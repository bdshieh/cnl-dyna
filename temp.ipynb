# %%
import numpy as np
from matplotlib import pyplot as plt
from cnld.api import layout, geometry, controldomain

lay = layout.matrix_layout(2, 2, 100e-6, 100e-6)

geom = geometry.circle_cmut_1mhz_geometry()
cdom = controldomain.autogenerate_control_domain(lay, geom)

# %%
plt.plot(np.array(cdom.center)[:, 0], np.array(cdom.center)[:, 1], 'o')
plt.gca().set_aspect('equal')

# %%
cdom[2]
# Out:
# ControlDomainData(id=2, position=[-5e-05, -5e-05, 0.0], shape='circle', lengthx=None, lengthy=None, radius_min=0.0, radius_max=1.1666666666666666e-05, theta_min=0.0, theta_max=1.5707963267948966, area=None)
